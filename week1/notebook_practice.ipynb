# %% [markdown]
# # NOTEBOOK LAB 1 - *MY AI JOURNEY*

# %% [markdown]
# ## GOAL
# I want to become a skilled AI Engineer by learning Python, machine learning, LLMs, RAG, and AI agents. My goal is to build real-world AI applications and create a strong portfolio for internships and future job opportunities.

# %% [markdown]
# ## Technologies I'll Learn
# * PYTHON
# * Git & GitHub
# * Cursor
# * Ollama
# * Large Language Models (LLMs)
# * RAG (Retrieval-Augmented Generation)
# * AI Agents
# * FastAPI
# * PostgreSQL
# * React

# %% [markdown]
# ## Today's Progress
# * Set up my AI development environment.
# * Learned the basics of Jupyter Notebooks.
# * Understood the difference between notebooks and Python scripts.
# * Learned about kernels and notebook execution.
# * Practiced Git by making my first commit and pushing it to GitHub.
# * Started building a consistent workflow for learning AI.
# ---
# ---

# %% [markdown]
# # NOTEBOOK LAB-2 - *Variables & Code Cells*

# %% [markdown]
# ## Exercise 1 – My Introduction
# ----
# <h3 align="center">Student Profile </h3>
#
# ------
# **Name**      : Pravalika K<br>
# **College**   : SIR MVIT<br>
# **Branch**    : ISE<br>
# **Semester**  : 5th<br>
# **Dream Job** : AI ENGINEER at MNC's<br>
# **Language**  : Telugu
#
# -------
# ------

# %% [markdown]
# ## Exercise 2 - Variables and Comments

# %%
#Store Student Details
details={
    "Name" : "Pravalika k",
    "Age" : 20,
    "USN" : 123
}

#Print Student Details
print(details)

#Print Student Name
print(details["Name"])

#Print Student Age
print(details["Age"])

#Print Student USN
print(details["USN"])
# Out:
# {'Name': 'Pravalika k', 'Age': 20, 'USN': 123}
# Pravalika k
# 20
# 123

# %% [markdown]
# -----
# ----

# %% [markdown]
# ## Exercise 3 – Update Variables

# %%
city="Bengaluru"

# %%
print(city)
# Out:
# Bengaluru

# %%
city="Mumbai"

# %%
print(city)
# Out:
# Mumbai

# %% [markdown]
# ------
# ------

# %% [markdown]
# ## Exercise 4 - Calculator

# %%
a=20
b=30

# %% [markdown]
#  <h4 align =center> Calculator </h4>
#  This program performs basic arithmetic operations on two numbers.

# %%
print("Addition of two numbers is :",a+b)
print("Subtraction of two numbers is :",a-b)
print("Multiplication of two numbers is :",a*b)
print("Division of two numbers is :",a/b)
print("Modulus of two numbers is :",a%b)
# Out:
# Addition of two numbers is : 50
# Subtraction of two numbers is : -10
# Multiplication of two numbers is : 600
# Division of two numbers is : 0.6666666666666666
# Modulus of two numbers is : 20

# %% [markdown]
# ----
# ----

# %% [markdown]
# ## Exercise 5 – String Practice

# %%
favFood="Paneer"
favMovie="Fidaa"
favHobby="Singing"
Name="Pravalika"
print("Hi! My name is " + Name+".I enjoy " + favHobby + ".I love having " + favFood + " and watching " + favMovie + ".")
# Out:
# Hi! My name is Pravalika.I enjoy Singing.I love having Paneer and watching Fidaa.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Exercise 6 - Experiment

# %%
age=20

# %%
print(age)
# Out:
# 20

# %%
age=21

# %% [markdown]
# When I ran the first cell again, Python reassigned the variable age from 20 to 21. The notebook's kernel updated the value stored in memory. Then, when I ran the second cell, it printed the new value (21) instead of the old one.
