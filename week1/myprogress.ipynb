# %% [markdown]
# ## 📅 AI Learning Journal – Day 1
#
# Date: 27 July 2026
#
# **✅ What I Learned Today**
# * Set up my LLM Engineering environment.
# * Understood the difference between Python notebooks and modules.
# * Learnt how to use Jupyter Notebooks and did some exercises
# * Learned the purpose of imports and commonly used libraries (os, dotenv, IPython.display, etc.).
# * Understood the concept of messages (role and content) used to communicate with LLMs.
# * Installed Ollama and downloaded the Llama 3.2 model locally.
# * Connected Ollama using the OpenAI Python SDK by configuring the base_url.
# * Successfully sent my first prompt to a locally running LLM and received a response.
# * Maintained different notebooks for progress,practice,explanation
#
# ---
#
# **💡 Biggest Takeaway**
# The same OpenAI SDK can be used with a local model like Ollama by simply changing the base_url. This lets me follow the course while running models locally without using the OpenAI API.
#
# ---
#
# **⚠️ Challenges Faced**
# Initial confusion between the Ollama Python library and the OpenAI SDK.
# Fixed the API client setup.
# Verified that long responses take longer because the model runs locally on my laptop.
#
# ---
#
# **🎯 Tomorrow's Goals**
# Continue Day 2 of the LLM Engineering course.
# Learn how prompts, responses, and chat completions work in more detail.
# Continue building the project using Ollama.
#
# ---
# ---

# %% [markdown]
# ### Day 2 – Website Summarizer & Prompt Engineering
#
# Date: 28 July 2026
#
# **🎯 Goal**
# Understand how prompts work and build my first AI application using a local LLM.
#
# ---
#
# **📚 Concepts Learned**
# - System Prompt
# - User Prompt
# - Message format (`role` & `content`)
# - Why prompts are defined separately
# - Why functions improve reusability and maintainability
# - How website content is fetched and passed to an LLM
# - Displaying responses in Markdown
#
# ---
#
# **💻 What I Built**
# - Built my first Website Summarizer using Ollama.
# - Tested the summarizer on different websites.
# - Experimented with a Job Description Summarizer by customizing the prompts.
#
# ---
#
# **🧠 Biggest Learnings***
# - LLMs work better with well-structured prompts.
# - Separating system and user prompts makes code easier to maintain.
# - Functions help make code reusable.
# - AI output depends on the quality of the input data.
# - Many modern job websites are JavaScript-based, so simple web scraping cannot extract complete job descriptions.
#
# ---
#
# **🚧 Challenges**
# - The Job Description Summarizer didn't work as expected because the webpage was a careers homepage rather than an actual job description.
# - Understanding why some websites can't be scraped using basic `requests` and `BeautifulSoup`.
#
# ---
#
# **📂 GitHub Progress**
# - Completed the Website Summarizer.
# - Created and pushed my customized Job Description Summarizer notebook.
#
# ---
#
# **🎯 Tommorrow's Goal**
# - Build an AI News Summarizer.
# - Start Day 2 of the LLM Engineering course.
#
# ---
# ---

# %% [markdown]
# ### Day 3 : Open API
#
# Date: 29 July 2026
#
# **📚 What I Learned**
# - Frontier Models (Closed-source vs Open-source)
# - Popular LLMs and their use cases
# - Three ways to use LLMs (Products, APIs, Local)
# - API Endpoints
# - Chat Completions API
# - OpenAI Python Client & OpenAI-Compatible APIs
# - How Ollama works behind the scenes
#
# ---
#
# **💻 What I Practiced**
# - Explored the Chat Completions API.
# - Compared direct HTTP requests with the OpenAI Python client.
# - Fixed the Ollama connection issue.
# - Ran different local models using Ollama:
#   - Llama 3.2
#   - Gemma
#   - DeepScaler
#
# ---
#
# **🚧 Challenges**
# - Initially faced a connection issue with Ollama.
# - Took time to understand endpoints, APIs, and how the OpenAI client works.
#
# ---
#
# **🎯 Tomorrow's Goal**
# - Start Day 3 of the LLM Engineering course.
# - Continue building and experimenting with LLM applications.
#
# ---
# ---

# %% [markdown]
# ### Day 4 :Frontier Models
#
# Date: 29 July 2026
#
# **📚 What I Learned**
# - Types of LLMs:
#   - Base Models
#   - Chat Models
#   - Reasoning Models
#   - Hybrid Models
# - Reasoning Budget & Budget Forcing
# - Strengths and limitations of Frontier LLMs
# - Comparison of GPT, Claude, Gemini, DeepSeek & Grok
# - ChatGPT features:
#   - Deep Research
#   - Agent Mode
#   - Image Generation
#
# **💻 What I Practiced**
# - Compared how different LLMs respond to conversation and reasoning prompts.
# - Explored ChatGPT's Deep Research, Agent Mode and Image Generation features.
# - Observed how the same prompt produces different outputs across different models.
# - Saw a Streamlit application for comparing LLM responses.
#
# **🚧 Challenges**
# - No major technical challenges today.
# - Focused on understanding the strengths and use cases of different models.
#
# **🎯 Tomorrow's Goal**
# - Start Day 4 of the LLM Engineering course.
# - Continue building hands-on AI applications.
#
# ---
# ---
