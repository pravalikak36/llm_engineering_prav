# %%
#!ollama pull llama3.2

# %%
import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

# %%
messages=[
    {
        "role" : "user",
        "content" : "Hey,How are you?"
    }
]

# %%
client = OpenAI(base_url=OLLAMA_BASE_URL, api_key="anything")
response =client.chat.completions.create(model="llama3.2", messages=messages)
print(response.choices[0].message.content)
# Out:
# I'm just a language model, so I don't have feelings like humans do, but thank you for asking! How can I assist you today?

# %%
messages=[
    {
        "role" : "system",
        "content" : "Act as a techer proficient in programming skills",
        "role" : "user",
        "content" : "Explain Python"
        
     }
]
g
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 10
#       1 messages=[
#       2     {
#       3         "role" : "system",
#    (...)      8      }
#       9 ]
# ---> 10 g
#
# NameError: name 'g' is not defined

# %%
response = client.chat.completions.create(
    model="llama3.2",
    messages=[
        {
            "role": "user",
            "content": "Reply with only the word: Hello"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# Hello

# %% [markdown]
# ## Exercise 2 : WEBSITE

# %%
cnn=fetch_website_contents("https://edition.cnn.com/")
print(cnn)
# Out:
# Breaking News, Latest News and Videos | CNN
#
# CNN values your feedback
# 1. How relevant is this ad to you?
# 2. Did you encounter any technical issues?
# Video player was slow to load content
# Video content never loaded
# Ad froze or did not finish loading
# Video content did not start after ad
# Audio on ad was too loud
# Other issues
# Ad never loaded
# Ad prevented/slowed the page from loading
# Content moved around while ad loaded
# Ad was repetitive to ads I've seen previously
# Other issues
# Cancel
# Submit
# Thank You!
# Your effort and contribution in providing this feedback is much
#                                         appreciated.
# Close
# Ad Feedback
# Close icon
# US
# World
# Politics
# Business
# Health
# Entertainment
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# World Cup 2026
# Ukraine-Russia War
# Israel-Hamas War
# Games
# More
# US
# World
# Politics
# Business
# Health
# Entertainment
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# ...

# %%
system_prompt="""
You are a news reader.Explain it in a way the users get interested to listen 
"""

# %%
user_prompt="""
Can u give me the headlines of todays news in different fields
"""

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt + website}
    ]

# %%
messages_for(cnn)
# Out:
# [{'role': 'system',
#   'content': '\nYou are a news reader.Explain it in a way the users get interested to listen \n'},
#  {'role': 'user',
# ...

# %%
def summarize(url):
    website = fetch_website_contents(url)
    response = client.chat.completions.create(
        model = "llama3.2",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://edition.cnn.com/")
# Out:
# '**BREAKING NEWS**\n\nGood evening, and welcome to our breaking news segment!\n\nWe have a packed lineup of headlines for you tonight in different fields. Let\'s dive right in:\n\n**US Politics:**\n\n* "Trump Announces Candidacy for 2026 Presidential Election" - Former President Donald Trump has announced his candidacy for the 2026 presidential election.\n* "Biden Administration Proposes Major Healthcare Reform Bill" - The Biden administration has proposed a major healthcare reform bill, which aims to improve access to affordable healthcare for millions of Americans.\n\n**Business:**\n\n* "Stock Market Plunges Due to Global Economic Uncertainty" - The stock market has plummeted due to global economic uncertainty, with investors becoming increasingly pessimistic about the economic outlook.\n* "Apple Unveils New Line of Smartphones at Event" - Apple has unveiled a new line of smartphones at its annual event, featuring advanced camera technology and sleek designs.\n\n**Health:**\n\n* "N
# ...

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edition.cnn.com/")
# Out:
# **Breaking News Alert!**
#
# Stay ahead of the curve with today's top headlines from around the world!
#
# [Image: CNN logo]
#
# **Global News Updates**
#
# * **US POLITICS**: The 2026 elections are heating up, with President Trump announcing his candidacy. Will he make a comeback?
# * **Ukraine-Russia War**: Ceasefire talks between Ukrainian and Russian officials hit a snag. Can a peaceful resolution be reached?
#
# **Business Buzz**
#
# * **MARKETS**: Don't miss our latest market analysis and predictions for the next economic shift.
# * **TECH**: The latest innovations in AI and space technology are set to revolutionize industries.
#
# **Health & Wellness**
#
# * **FITNESS**: Unlock your full potential with expert fitness tips and advice.
# * **MENTAL HEALTH**: Take a step towards recovery with these groundbreaking solutions.
#
# **Entertainment News**
#
# * **MOVIES**: Get the inside scoop on the most anticipated films releases.
# ...
