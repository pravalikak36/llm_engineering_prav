# %% [markdown]
# Variables

# %%
print(
    "name : pravalika"
    "\nage : 20"
    "\ncity : hyderabad"
)
# Out:
# name : pravalika
# age : 20
# city : hyderabad

# %%
x=10
y=20

# %%
print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# 30
# -10
# 200
# 0.5

# %%
x=30

# %%
print(x)
# Out:
# 10

# %% [markdown]
# Here x showed 10 becuse after redeclaration of x value is 30 we dint run the previous x value

# %%
print(x)
# Out:
# 30
